# %% [markdown]
# # Fanta Scraping

# %%
import bs4
import urllib
import pandas as pd
import re
import requests
import numpy as np
from IPython.core.display import display, HTML

# %% [markdown]
# ## Importa nomi squadre

# %%
url = 'http://leghe.fantagazzetta.com/fantascandalo/tutte-le-rose'
# url = 'http://leghe.fantagazzetta.com/fantascandalo/calendario'
source = requests.get(url)
soup = bs4.BeautifulSoup(source.content, "lxml")

# print(soup.prettify())

tr = soup.find_all('tr')
team_names = []
for i in tr:
    trows = [k.string for k in i.children]
    for j in range(len(trows)):
        if trows[j] == "squadra":
            team_names.append(trows[j-1])  
            print(trows[j-1])
# Out:
# FC ROXY
# FC Pastaboy
# Bucalina FC
# Fc Stress
# Ciolle United
# AC PICCHIA
# FC BOMBAGALLO
# LA CORRAZZATA POTEMKIN

# %%
print(team_names)
# Out:
# ['FC ROXY', 'FC Pastaboy', 'Bucalina FC', 'Fc Stress', 'Ciolle United', 'AC PICCHIA', 'FC BOMBAGALLO', 'LA CORRAZZATA POTEMKIN']

# %%
a = np.empty((36,8,))
a[:] = np.nan

# %%
df_teams = pd.DataFrame(data = a, index = np.arange(36)+1, columns=team_names)
df_teams.head()
# Out:
#    FC ROXY  FC Pastaboy  Bucalina FC  Fc Stress  Ciolle United  AC PICCHIA  \
# 1      NaN          NaN          NaN        NaN            NaN         NaN
# 2      NaN          NaN          NaN        NaN            NaN         NaN
# 3      NaN          NaN          NaN        NaN            NaN         NaN
# 4      NaN          NaN          NaN        NaN            NaN         NaN
# 5      NaN          NaN          NaN        NaN            NaN         NaN
#
#    FC BOMBAGALLO  LA CORRAZZATA POTEMKIN
# 1            NaN                     NaN
# 2            NaN                     NaN
# 3            NaN                     NaN
# 4            NaN                     NaN
# 5            NaN                     NaN

# %%
df_teams['FC ROXY'][2] = 1
df_teams.head()
# Out:
#    FC ROXY  FC Pastaboy  Bucalina FC  Fc Stress  Ciolle United  AC PICCHIA  \
# 1      NaN          NaN          NaN        NaN            NaN         NaN
# 2      1.0          NaN          NaN        NaN            NaN         NaN
# 3      NaN          NaN          NaN        NaN            NaN         NaN
# 4      NaN          NaN          NaN        NaN            NaN         NaN
# 5      NaN          NaN          NaN        NaN            NaN         NaN
#
#    FC BOMBAGALLO  LA CORRAZZATA POTEMKIN
# 1            NaN                     NaN
# 2            NaN                     NaN
# 3            NaN                     NaN
# 4            NaN                     NaN
# 5            NaN                     NaN

# %% [markdown]
# ## Importa punti per giornata

# %%
url = 'http://leghe.fantagazzetta.com/fantascandalo/calendario'
source = requests.get(url)
soup = bs4.BeautifulSoup(source.content, "lxml")
tr = soup.find_all('tr')

# %%
squadre = []
trows = []
for i in tr:
    
    trows = [k for k in i.children]
    for j in trows:
        print_risultato(j)
        if 'GIORNATA' in 
    print('\n\n')
#     for j in range(len(trows)):
#         pass
# #         if trows[j] == "GIORNATA":
# #             print(trows[j-1])
#         print()
#         if type(trows[j]) != str:
#             print_risultato(trows[j])
#         else:
#             print('String: ' + trows[j])
#     print('\n\n')
# Out:
# 1a GIORNATA - 2a Serie A
#
#
#
# FC Pastaboy
#
# 67,50
#  -
# 75,00
#
# Bucalina FC
# 1-2
#
#
#
# FC ROXY
#
# 80,00
#  -
# 83,00
#
# Ciolle United
# 3-3
#
#
#
# Fc Stress
#
# 61,00
#  -
# 75,00
#
# AC PICCHIA
# 0-2
#
#
#
# FC BOMBAGALLO
#
# 64,50
#  -
# 64,50
#
# LA CORRAZZATA POTEMKIN
# 0-0
#
#
#
# Dettagli 1ª giornata
#
#
#
# 2a GIORNATA - 3a Serie A
#
#
#
# Bucalina FC
#
# 79,50
#  -
# 72,50
#
# FC BOMBAGALLO
# 3-2
#
#
#
# LA CORRAZZATA POTEMKIN
#
# 79,00
#  -
# 65,00
#
# Fc Stress
# 3-0
#
#
#
# AC PICCHIA
#
# 71,50
#  -
# 68,50
#
# FC ROXY
# 1-1
#
#
#
# Ciolle United
#
# 68,00
#  -
# 78,50
#
# FC Pastaboy
# 1-3
#
#
#
# Dettagli 2ª giornata
#
#
#
# 3a GIORNATA - 4a Serie A
#
#
#
# FC ROXY
#
# 69,50
#  -
# 82,00
#
# LA CORRAZZATA POTEMKIN
# 1-3
#
#
#
# Fc Stress
#
# 74,00
#  -
# 62,50
#
# Bucalina FC
# 2-0
#
#
#
# FC BOMBAGALLO
#
# 68,00
#  -
# 77,50
#
# FC Pastaboy
# 1-2
#
#
#
# AC PICCHIA
#
# 64,00
#  -
# 71,00
#
# Ciolle United
# 0-1
#
#
#
# Dettagli 3ª giornata
#
#
#
# 4a GIORNATA - 5a Serie A
#
#
#
# FC Pastaboy
#
# 72,00
#  -
# 71,50
#
# Fc Stress
# 2-1
#
#
#
# Bucalina FC
#
# 79,50
#  -
# 71,00
#
# FC ROXY
# 3-1
#
#
#
# LA CORRAZZATA POTEMKIN
#
# 77,50
#  -
# 75,00
#
# AC PICCHIA
# 2-2
#
#
#
# Ciolle United
#
# 75,50
#  -
# 73,00
#
# FC BOMBAGALLO
# 2-2
#
#
#
# Dettagli 4ª giornata
#
#
#
# 5a GIORNATA - 6a Serie A
#
#
#
# FC ROXY
#
# 69,00
#  -
# 77,00
#
# FC Pastaboy
# 1-2
#
#
#
# Fc Stress
#
# 65,00
#  -
# 64,50
#
# FC BOMBAGALLO
# 0-0
#
#
#
# LA CORRAZZATA POTEMKIN
#
# 67,00
#  -
# 70,50
#
# Ciolle United
# 1-1
#
#
#
# AC PICCHIA
#
# 55,50
#  -
# 66,00
#
# Bucalina FC
# 0-1
#
#
#
# Dettagli 5ª giornata
#
#
#
# 6a GIORNATA - 7a Serie A
#
#
#
# FC Pastaboy
#
# 65,50
#  -
# 65,00
#
# AC PICCHIA
# 0-0
#
#
#
# Bucalina FC
#
# 73,50
#  -
# 59,50
#
# LA CORRAZZATA POTEMKIN
# 2-0
#
#
#
# Fc Stress
#
# 65,50
#  -
# 70,50
#
# Ciolle United
# 0-1
#
#
#
# FC BOMBAGALLO
#
# 74,00
#  -
# 68,00
#
# FC ROXY
# 2-1
#
#
#
# Dettagli 6ª giornata
#
#
#
# 7a GIORNATA - 8a Serie A
#
#
#
# FC ROXY
#
# 68,00
#  -
# 64,00
#
# Fc Stress
# 1-0
#
#
#
# LA CORRAZZATA POTEMKIN
#
# 63,00
#  -
# 65,00
#
# FC Pastaboy
# 0-0
#
#
#
# AC PICCHIA
#
# 72,00
#  -
# 71,00
#
# FC BOMBAGALLO
# 2-1
#
#
#
# Ciolle United
#
# 72,50
#  -
# 77,50
#
# Bucalina FC
# 2-2
#
#
#
# Dettagli 7ª giornata
#
#
#
# 8a GIORNATA - 9a Serie A
#
#
#
# Bucalina FC
#
# 71,00
#  -
# 69,50
#
# FC Pastaboy
# 1-1
#
#
#
# Ciolle United
#
# 63,50
#  -
# 82,50
#
# FC ROXY
# 0-3
#
#
#
# AC PICCHIA
#
# 77,00
#  -
# 83,00
#
# Fc Stress
# 2-3
#
#
#
# LA CORRAZZATA POTEMKIN
#
# 75,00
#  -
# 67,00
#
# FC BOMBAGALLO
# 2-1
#
#
#
# Dettagli 8ª giornata
#
#
#
# 9a GIORNATA - 10a Serie A
#
#
#
# FC BOMBAGALLO
#
# 52,50
#  -
# 69,50
#
# Bucalina FC
# 0-1
#
#
#
# Fc Stress
#
# 65,50
#  -
# 76,00
#
# LA CORRAZZATA POTEMKIN
# 0-2
#
#
#
# FC ROXY
#
# 79,00
#  -
# 79,50
#
# AC PICCHIA
# 3-3
#
#
#
# FC Pastaboy
#
# 73,00
#  -
# 76,00
#
# Ciolle United
# 2-2
#
#
#
# Dettagli 9ª giornata
#
#
#
# 10a GIORNATA - 11a Serie A
#
#
#
# LA CORRAZZATA POTEMKIN
#
# 63,50
#  -
# 75,00
#
# FC ROXY
# 0-2
#
#
#
# Bucalina FC
#
# 72,50
#  -
# 74,00
#
# Fc Stress
# 2-2
#
#
#
# FC Pastaboy
#
# 71,50
#  -
# 63,00
#
# FC BOMBAGALLO
# 1-0
#
#
#
# Ciolle United
#
# 77,50
#  -
# 69,50
#
# AC PICCHIA
# 2-1
#
#
#
# Dettagli 10ª giornata
#
#
#
# 11a GIORNATA - 12a Serie A
#
#
#
# Fc Stress
#
# 71,50
#  -
# 58,00
#
# FC Pastaboy
# 1-0
#
#
#
# FC ROXY
#
# 58,50
#  -
# 82,50
#
# Bucalina FC
# 0-3
#
#
#
# AC PICCHIA
#
# 79,50
#  -
# 79,50
#
# LA CORRAZZATA POTEMKIN
# 3-3
#
#
#
# FC BOMBAGALLO
#
# 62,00
#  -
# 87,50
#
# Ciolle United
# 0-4
#
#
#
# Dettagli 11ª giornata
#
#
#
# 12a GIORNATA - 13a Serie A
#
#
#
# FC Pastaboy
#
# 73,50
#  -
# 75,50
#
# FC ROXY
# 2-2
#
#
#
# FC BOMBAGALLO
#
# 62,50
#  -
# 68,50
#
# Fc Stress
# 0-1
#
#
#
# Ciolle United
#
# 78,50
#  -
# 77,50
#
# LA CORRAZZATA POTEMKIN
# 3-2
#
#
#
# Bucalina FC
#
# 66,50
#  -
# 78,50
#
# AC PICCHIA
# 1-3
#
#
#
# Dettagli 12ª giornata
#
#
#
# 13a GIORNATA - 14a Serie A
#
#
#
# AC PICCHIA
#
# 85,50
#  -
# 69,00
#
# FC Pastaboy
# 4-1
#
#
#
# LA CORRAZZATA POTEMKIN
#
# 80,50
#  -
# 69,00
#
# Bucalina FC
# 3-1
#
#
#
# Ciolle United
#
# 65,50
#  -
# 67,50
#
# Fc Stress
# 0-1
#
#
#
# FC ROXY
#
# 61,00
#  -
# 82,00
#
# FC BOMBAGALLO
# 0-3
#
#
#
# Dettagli 13ª giornata
#
#
#
# 14a GIORNATA - 15a Serie A
#
#
#
# Fc Stress
#
# 66,00
#  -
# 71,00
#
# FC ROXY
# 1-1
#
#
#
# FC Pastaboy
#
# 72,50
#  -
# 65,00
#
# LA CORRAZZATA POTEMKIN
# 2-0
#
#
#
# FC BOMBAGALLO
#
# 65,00
#  -
# 63,50
#
# AC PICCHIA
# 0-0
#
#
#
# Bucalina FC
#
# 70,00
#  -
# 68,00
#
# Ciolle United
# 1-1
#
#
#
# Dettagli 14ª giornata
#
#
#
# 15a GIORNATA - 16a Serie A
#
#
#
# FC Pastaboy
#
# 98,00
#  -
# 59,50
#
# Bucalina FC
# 6-0
#
#
#
# FC ROXY
#
# 75,50
#  -
# 78,50
#
# Ciolle United
# 2-3
#
#
#
# Fc Stress
#
# 73,00
#  -
# 71,50
#
# AC PICCHIA
# 2-1
#
#
#
# FC BOMBAGALLO
#
# 74,00
#  -
# 59,00
#
# LA CORRAZZATA POTEMKIN
# 2-0
#
#
#
# Dettagli 15ª giornata
#
#
#
# 16a GIORNATA - 17a Serie A
#
#
#
# Bucalina FC
#
# 67,00
#  -
# 64,00
#
# FC BOMBAGALLO
# 1-0
#
#
#
# LA CORRAZZATA POTEMKIN
#
# 64,00
#  -
# 59,50
#
# Fc Stress
# 0-0
#
#
#
# AC PICCHIA
#
# 70,00
#  -
# 74,50
#
# FC ROXY
# 1-2
#
#
#
# Ciolle United
#
# 68,50
#  -
# 94,50
#
# FC Pastaboy
# 1-5
#
#
#
# Dettagli 16ª giornata
#
#
#
# 17a GIORNATA - 18a Serie A
#
#
#
# FC ROXY
#
# 67,50
#  -
# 72,00
#
# LA CORRAZZATA POTEMKIN
# 1-2
#
#
#
# Fc Stress
#
# 62,00
#  -
# 70,50
#
# Bucalina FC
# 0-1
#
#
#
# FC BOMBAGALLO
#
# 72,00
#  -
# 71,50
#
# FC Pastaboy
# 2-1
#
#
#
# AC PICCHIA
#
# 73,00
#  -
# 80,00
#
# Ciolle United
# 2-3
#
#
#
# Dettagli 17ª giornata
#
#
#
# 18a GIORNATA - 19a Serie A
#
#
#
# FC Pastaboy
#
# 71,00
#  -
# 83,00
#
# Fc Stress
# 1-3
#
#
#
# Bucalina FC
#
# 69,50
#  -
# 74,50
#
# FC ROXY
# 1-2
#
#
#
# LA CORRAZZATA POTEMKIN
#
# 70,00
#  -
# 65,50
#
# AC PICCHIA
# 1-0
#
#
#
# Ciolle United
#
# 67,00
#  -
# 69,50
#
# FC BOMBAGALLO
# 1-1
#
#
#
# Dettagli 18ª giornata
#
#
#
# 19a GIORNATA - 20a Serie A
#
#
#
# FC ROXY
#
# 69,50
#  -
# 81,50
#
# FC Pastaboy
# 1-3
#
#
#
# Fc Stress
#
# 81,50
#  -
# 82,00
#
# FC BOMBAGALLO
# 3-3
#
#
#
# LA CORRAZZATA POTEMKIN
#
# 72,50
#  -
# 61,00
#
# Ciolle United
# 2-0
#
#
#
# AC PICCHIA
#
# 69,00
#  -
# 65,00
#
# Bucalina FC
# 1-0
#
#
#
# Dettagli 19ª giornata
#
#
#
# 20a GIORNATA - 21a Serie A
#
#
#
# FC Pastaboy
#
# 74,00
#  -
# 66,00
#
# AC PICCHIA
# 2-1
#
#
#
# Bucalina FC
#
# 73,50
#  -
# 70,00
#
# LA CORRAZZATA POTEMKIN
# 2-1
#
#
#
# Fc Stress
#
# 78,00
#  -
# 72,00
#
# Ciolle United
# 3-2
#
#
#
# FC BOMBAGALLO
#
# 82,50
#  -
# 69,00
#
# FC ROXY
# 3-1
#
#
#
# Dettagli 20ª giornata
#
#
#
# 21a GIORNATA - 22a Serie A
#
#
#
# FC ROXY
#
# 65,00
#  -
# 73,00
#
# Fc Stress
# 0-2
#
#
#
# LA CORRAZZATA POTEMKIN
#
# 80,00
#  -
# 73,00
#
# FC Pastaboy
# 3-2
#
#
#
# AC PICCHIA
#
# 68,50
#  -
# 67,50
#
# FC BOMBAGALLO
# 1-1
#
#
#
# Ciolle United
#
# 70,00
#  -
# 82,50
#
# Bucalina FC
# 1-3
#
#
#
# Dettagli 21ª giornata
#
#
#
# 22a GIORNATA - 23a Serie A
#
#
#
# Bucalina FC
#
# 76,00
#  -
# 96,00
#
# FC Pastaboy
# 2-6
#
#
#
# Ciolle United
#
# 72,00
#  -
# 85,50
#
# FC ROXY
# 2-4
#
#
#
# AC PICCHIA
#
# 70,00
#  -
# 66,00
#
# Fc Stress
# 1-1
#
#
#
# LA CORRAZZATA POTEMKIN
#
# 77,50
#  -
# 76,50
#
# FC BOMBAGALLO
# 2-2
#
#
#
# Dettagli 22ª giornata
#
#
#
# 23a GIORNATA - 24a Serie A
#
#
#
# FC BOMBAGALLO
#
# 70,50
#  -
# 76,00
#
# Bucalina FC
# 1-2
#
#
#
# Fc Stress
#
# 81,00
#  -
# 75,00
#
# LA CORRAZZATA POTEMKIN
# 3-2
#
#
#
# FC ROXY
#
# 75,00
#  -
# 74,00
#
# AC PICCHIA
# 2-2
#
#
#
# FC Pastaboy
#
# 85,50
#  -
# 77,50
#
# Ciolle United
# 4-2
#
#
#
# Dettagli 23ª giornata
#
#
#
# 24a GIORNATA - 25a Serie A
#
#
#
# LA CORRAZZATA POTEMKIN
#
# 71,50
#  -
# 77,50
#
# FC ROXY
# 1-2
#
#
#
# Bucalina FC
#
# 75,00
#  -
# 74,50
#
# Fc Stress
# 2-2
#
#
#
# FC Pastaboy
#
# 76,50
#  -
# 81,50
#
# FC BOMBAGALLO
# 2-3
#
#
#
# Ciolle United
#
# 66,50
#  -
# 68,00
#
# AC PICCHIA
# 1-1
#
#
#
# Dettagli 24ª giornata
#
#
#
# 25a GIORNATA - 26a Serie A
#
#
#
# Fc Stress
#
# 76,00
#  -
# 64,00
#
# FC Pastaboy
# 2-0
#
#
#
# FC ROXY
#
# 85,00
#  -
# 68,00
#
# Bucalina FC
# 4-1
#
#
#
# AC PICCHIA
#
# 64,00
#  -
# 73,00
#
# LA CORRAZZATA POTEMKIN
# 0-2
#
#
#
# FC BOMBAGALLO
#
# 63,00
#  -
# 70,00
#
# Ciolle United
# 0-1
#
#
#
# Dettagli 25ª giornata
#
#
#
# 26a GIORNATA - 27a Serie A
#
#
#
# FC Pastaboy
#
# 78,00
#  -
# 71,00
#
# FC ROXY
# 3-1
#
#
#
# FC BOMBAGALLO
#
# 67,50
#  -
# 82,00
#
# Fc Stress
# 1-3
#
#
#
# Ciolle United
#
# 77,50
#  -
# 79,50
#
# LA CORRAZZATA POTEMKIN
# 2-3
#
#
#
# Bucalina FC
#
# 74,50
#  -
# 68,00
#
# AC PICCHIA
# 2-1
#
#
#
# Dettagli 26ª giornata
#
#
#
# 27a GIORNATA - 28a Serie A
#
#
#
# AC PICCHIA
#  -
# FC Pastaboy
#
#
#
# LA CORRAZZATA POTEMKIN
#  -
# Bucalina FC
#
#
#
# Ciolle United
#  -
# Fc Stress
#
#
#
# FC ROXY
#  -
# FC BOMBAGALLO
#
#
#
#
#
#
# 28a GIORNATA - 29a Serie A
#
#
#
# Fc Stress
#  -
# FC ROXY
#
#
#
# FC Pastaboy
#  -
# LA CORRAZZATA POTEMKIN
#
#
#
# FC BOMBAGALLO
#  -
# AC PICCHIA
#
#
#
# Bucalina FC
#  -
# Ciolle United
#
#
#
#
#
#
# 29a GIORNATA - 30a Serie A
#
#
#
# FC Pastaboy
#  -
# Bucalina FC
#
#
#
# FC ROXY
#  -
# Ciolle United
#
#
#
# Fc Stress
#  -
# AC PICCHIA
#
#
#
# FC BOMBAGALLO
#  -
# LA CORRAZZATA POTEMKIN
#
#
#
#
#
#
# 30a GIORNATA - 31a Serie A
#
#
#
# Bucalina FC
#  -
# FC BOMBAGALLO
#
#
#
# LA CORRAZZATA POTEMKIN
#  -
# Fc Stress
#
#
#
# AC PICCHIA
#  -
# FC ROXY
#
#
#
# Ciolle United
#  -
# FC Pastaboy
#
#
#
#
#
#
# 31a GIORNATA - 32a Serie A
#
#
#
# FC ROXY
#  -
# LA CORRAZZATA POTEMKIN
#
#
#
# Fc Stress
#  -
# Bucalina FC
#
#
#
# FC BOMBAGALLO
#  -
# FC Pastaboy
#
#
#
# AC PICCHIA
#  -
# Ciolle United
#
#
#
#
#
#
# 32a GIORNATA - 33a Serie A
#
#
#
# FC Pastaboy
#  -
# Fc Stress
#
#
#
# Bucalina FC
#  -
# FC ROXY
#
#
#
# LA CORRAZZATA POTEMKIN
#  -
# AC PICCHIA
#
#
#
# Ciolle United
#  -
# FC BOMBAGALLO
#
#
#
#
#
#
# 33a GIORNATA - 34a Serie A
#
#
#
# FC ROXY
#  -
# FC Pastaboy
#
#
#
# Fc Stress
#  -
# FC BOMBAGALLO
#
#
#
# LA CORRAZZATA POTEMKIN
#  -
# Ciolle United
#
#
#
# AC PICCHIA
#  -
# Bucalina FC
#
#
#
#
#
#
# 34a GIORNATA - 35a Serie A
#
#
#
# FC Pastaboy
#  -
# AC PICCHIA
#
#
#
# Bucalina FC
#  -
# LA CORRAZZATA POTEMKIN
#
#
#
# Fc Stress
#  -
# Ciolle United
#
#
#
# FC BOMBAGALLO
#  -
# FC ROXY
#
#
#
#
#
#
# 35a GIORNATA - 36a Serie A
#
#
#
# FC ROXY
#  -
# Fc Stress
#
#
#
# LA CORRAZZATA POTEMKIN
#  -
# FC Pastaboy
#
#
#
# AC PICCHIA
#  -
# FC BOMBAGALLO
#
#
#
# Ciolle United
#  -
# Bucalina FC

# %%
for i in trows:
    print_risultato(i)

# %%
print(trows[1])
# Out:
# [<td class="match"><span class="ssteam tleft"><a href="http://leghe.fantagazzetta.com/fantascandalo/dettaglio-rosa/fc-pastaboy/1102066" title="Visualizza i dettagli della squadra FC Pastaboy">FC Pastaboy</a></span> <span class="point">67,50</span> - <span class="point">75,00</span> <span class="ssteam tright"><a href="http://leghe.fantagazzetta.com/fantascandalo/dettaglio-rosa/bucalina-fc/1101833" title="Visualizza i dettagli della squadra Bucalina FC">Bucalina FC</a></span></td>, <td class="result">1-2</td>]

# %%
type(trows[0])
# Out:
# bs4.element.Tag

# %%
def print_risultato(test):
    
    if type(test) is bs4.element.Tag:
        for i in test.children:
            print_risultato(i)
    else:
        print(test)
        return(test)
